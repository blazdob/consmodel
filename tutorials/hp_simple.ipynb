# %%
import requests
from consmodel import HP, PV
from datetime import datetime
import numpy as np

 
lat, lon, alt = 46.234799542032, 14.3423120793485, 400.0

hp = HP(lat, lon, alt)

start = datetime(2022, 4, 1)
end = datetime(2023, 4, 1)

timeseries = hp.simulate(22.0, start=start, end=end, freq='15min')

# %%
timeseries.plot()
# Out:
# <AxesSubplot: xlabel='time'>
