# %% [markdown]
# # Simple example of creating a PV model

# %%
from consmodel import PV
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# create a simple PV model
pv = PV(lat=46.155768,
        lon=14.304951,
        alt=400,
        index=1,
        name="test",
        tz="Europe/Vienna")

# %%
timeseries = pv.simulate(pv_size=14.,
                         year=2022,
                         freq="15min",
                         model="ineichen",
                         consider_cloud_cover=True)

# %%
pv.results.p
# Out:
# 2022-01-01 00:15:00+01:00    0.0
# 2022-01-01 00:30:00+01:00    0.0
# 2022-01-01 00:45:00+01:00    0.0
# 2022-01-01 01:00:00+01:00    0.0
# 2022-01-01 01:15:00+01:00    0.0
#                             ...
# 2022-12-31 23:00:00+01:00    0.0
# 2022-12-31 23:15:00+01:00    0.0
# 2022-12-31 23:30:00+01:00    0.0
# 2022-12-31 23:45:00+01:00    0.0
# 2023-01-01 00:00:00+01:00    0.0
# Freq: 15T, Name: P, Length: 35040, dtype: float64

# %%
timeseries.plot()
plt.show()

# %%
def show_week(df, week):
    df = df.loc[df.index.week == week]
    df.plot()
    plt.show()

show_week(timeseries, 1)

# %% [markdown]
# ## Backend all results

# %% [markdown]
# All backend results are stored in the `self.results` folder. The results are stored in the following format:
#
# the Dataframe results format is different based on the element type. For example, for a PV element, the results are stored in the following format:
#
# 'ghi', 'dhi', 'dni', 'temp', 'dwpt', 'rhum', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres', 'tsun', 'coco', 'poa_global', 'temp_pv', 'eta_rel', 'coco_mask', 'P'

# %%
pv.results
# Out:
#                            ghi  dhi  dni   temp   dwpt  rhum  prcp  snow  \
# 2022-01-01 00:15:00+01:00  0.0  0.0  0.0 -2.775 -3.175  97.0   0.0   NaN
# 2022-01-01 00:30:00+01:00  0.0  0.0  0.0 -2.950 -3.350  97.0   0.0   NaN
# 2022-01-01 00:45:00+01:00  0.0  0.0  0.0 -3.125 -3.525  97.0   0.0   NaN
# 2022-01-01 01:00:00+01:00  0.0  0.0  0.0 -3.300 -3.700  97.0   0.0   NaN
# 2022-01-01 01:15:00+01:00  0.0  0.0  0.0 -3.475 -3.875  97.0   0.0   NaN
# ...                        ...  ...  ...    ...    ...   ...   ...   ...
# 2022-12-31 23:00:00+01:00  0.0  0.0  0.0  2.600  2.500  99.0   0.0   0.0
# 2022-12-31 23:15:00+01:00  0.0  0.0  0.0  2.850  2.750  99.0   0.0   0.0
# 2022-12-31 23:30:00+01:00  0.0  0.0  0.0  3.100  3.000  99.0   0.0   0.0
# 2022-12-31 23:45:00+01:00  0.0  0.0  0.0  3.350  3.250  99.0   0.0   0.0
# 2023-01-01 00:00:00+01:00  0.0  0.0  0.0  3.600  3.500  99.0   0.0   0.0
#
#                              wdir   wspd   wpgt      pres  tsun  coco  \
# ...
